# %%
import pandas as pd
import numpy as np 

df_all = pd.read_csv("data/df_Decks_tidy.csv")
df_card_dict = pd.read_csv("data/df_cards.csv")

# %%
QQ = list(df_all.columns)

QQ
# Out:
# ['Unnamed: 0',
#  'win_rate_RE',
#  'time_duration_RE',
#  'game_count_RE',
#  'dust_cost',
#  'Warrior',
#  'Warlock',
#  'Shaman',
#  'Rogue',
#  'Priest',
#  'Paladin',
#  'Mage',
#  'Hunter',
#  'Druid',
#  'Demon Hunter',
#  'Deck_URL',
#  'Deck_Name',
#  'Deck_ID',
#  'Card_999',
#  'Card_997',
#  'Card_995',
#  'Card_994',
#  'Card_985',
#  'Card_976',
#  'Card_974',
#  'Card_971',
#  'Card_960',
#  'Card_950',
#  'Card_95',
#  'Card_943',
#  'Card_932',
#  'Card_922',
#  'Card_921',
#  'Card_919',
#  'Card_914',
#  'Card_912',
#  'Card_906',
#  'Card_904',
#  'Card_903',
#  'Card_90',
#  'Card_896',
#  'Card_890',
#  'Card_878',
#  'Card_877',
#  'Card_866',
#  'Card_864',
#  'Card_860',
#  'Card_86',
#  'Card_859',
#  'Card_847',
#  'Card_841',
#  'Card_836',
#  'Card_830',
#  'Card_818',
#  'Card_814',
#  'Card_811',
#  'Card_804',
#  'Card_8',
#  'Card_791',
#  'Card_790',
#  'Card_785',
#  'Card_778',
#  'Card_777',
#  'Card_77',
#  'Card_768',
#  'Card_767',
# ...

# %%
df_all.tail(10)
# Out:
#        Unnamed: 0  win_rate_RE  time_duration_RE  game_count_RE  dust_cost  \
# 16716       16716         53.4               6.4            290       6420
# 16717       16717         53.4              11.9            260      15020
# 16718       16718         61.2               9.0            260       9340
# 16719       16719         59.3              11.1            260      11900
# 16720       16720         53.5               9.0            250       7400
# 16721       16721         61.1              10.0            250      10520
# 16722       16722         57.5               8.5            240      12120
# 16723       16723         52.3               9.6            240      13460
# 16724       16724         54.8              11.7            200      11800
# 16725       16725         55.9              11.7            200      16600
#
#        Warrior  Warlock  Shaman  Rogue  Priest  ...  Card_1035  Card_1029  \
# ...
